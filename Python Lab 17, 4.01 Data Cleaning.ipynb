# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')
data.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %% [markdown]
# # review data

# %%
data.dtypes
# Out:
# Customer                          object
# State                             object
# Customer Lifetime Value          float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Renew Offer Type                  object
# Sales Channel                     object
# Total Claim Amount               float64
# Vehicle Class                     object
# ...

# %%
#fix headers to PE8
data.columns = data.columns.str.lower().str.replace(" ","_")
data.rename(columns = {"employmentstatus" : "employment_status"}, inplace = True)
data.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   effective_to_date employment_status gender  income  ...  \
# 0           2/24/11          Employed      F   56274  ...
# 1           1/31/11        Unemployed      F       0  ...
# 2           2/19/11          Employed      F   48767  ...
# 3           1/20/11        Unemployed      M       0  ...
# 4            2/3/11          Employed      M   43836  ...
#
#   months_since_policy_inception number_of_open_complaints  number_of_policies  \
# ...

# %%
#change effective to date column to datetime format
data['effective_to_date'] =  pd.to_datetime(data['effective_to_date'])
data.dtypes
# Out:
# customer                                 object
# state                                    object
# customer_lifetime_value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective_to_date                datetime64[ns]
# employment_status                        object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_last_claim                   int64
# months_since_policy_inception             int64
# number_of_open_complaints                 int64
# number_of_policies                        int64
# policy_type                              object
# policy                                   object
# renew_offer_type                         object
# ...

# %%
#checking NaN's 

pd.DataFrame(data.isna().sum()/len(data))
X_num = data.select_dtypes(include = np.number)
X_cat = data.select_dtypes(include = np.object)# no NaN available, nothing to change
# Out:
#                                  0
# customer                       0.0
# state                          0.0
# customer_lifetime_value        0.0
# response                       0.0
# coverage                       0.0
# education                      0.0
# effective_to_date              0.0
# employment_status              0.0
# gender                         0.0
# income                         0.0
# location_code                  0.0
# marital_status                 0.0
# monthly_premium_auto           0.0
# months_since_last_claim        0.0
# months_since_policy_inception  0.0
# number_of_open_complaints      0.0
# number_of_policies             0.0
# policy_type                    0.0
# policy                         0.0
# renew_offer_type               0.0
# sales_channel                  0.0
# total_claim_amount             0.0
# vehicle_class                  0.0
# vehicle_size                   0.0

# %%
#reviewing dtype split results
X_num = data.select_dtypes(include = np.number)
categorical = data.select_dtypes(include = np.object)

# %%
X_num.head()
# Out:
#    customer_lifetime_value  income  monthly_premium_auto  \
# 0              2763.519279   56274                    69
# 1              6979.535903       0                    94
# 2             12887.431650   48767                   108
# 3              7645.861827       0                   106
# 4              2813.692575   43836                    73
#
#    months_since_last_claim  months_since_policy_inception  \
# 0                       32                              5
# 1                       13                             42
# 2                       18                             38
# 3                       18                             65
# 4                       12                             44
#
#    number_of_open_complaints  number_of_policies  total_claim_amount
# 0                          0                   1          384.811147
# 1                          0                   8         1131.464935
# ...

# %%
categorical.head()
# Out:
#   customer       state response  coverage education employment_status gender  \
# 0  BU79786  Washington       No     Basic  Bachelor          Employed      F
# 1  QZ44356     Arizona       No  Extended  Bachelor        Unemployed      F
# 2  AI49188      Nevada       No   Premium  Bachelor          Employed      F
# 3  WW63253  California       No     Basic  Bachelor        Unemployed      M
# 4  HB64268  Washington       No     Basic  Bachelor          Employed      M
#
#   location_code marital_status     policy_type        policy renew_offer_type  \
# 0      Suburban        Married  Corporate Auto  Corporate L3           Offer1
# 1      Suburban         Single   Personal Auto   Personal L3           Offer3
# 2      Suburban        Married   Personal Auto   Personal L3           Offer1
# 3      Suburban        Married  Corporate Auto  Corporate L2           Offer1
# 4         Rural         Single   Personal Auto   Personal L1           Offer1
#
# ...

# %% [markdown]
# # Q7

# %% [markdown]
# Define a function that differentiates between continuous and discrete variables. Hint: A number of unique values might be useful. Store continuous data into a continuous variable and do the same for discrete and categorical.

# %%
numcols = data.select_dtypes(np.number)
numcols_list = list(numcols.columns)
discrete = []
continuous = []
for col in numcols_list:
    item_counts = data[col].value_counts()
    print(col, ': ', len(item_counts))
    if len(item_counts) > 50:
        continuous.append(col)
    else:
        discrete.append(col)
discrete.append('effective_to_date')

print(discrete)
print(continuous)
# Out:
# customer_lifetime_value :  8041
# income :  5694
# monthly_premium_auto :  202
# months_since_last_claim :  36
# months_since_policy_inception :  100
# number_of_open_complaints :  6
# number_of_policies :  9
# total_claim_amount :  5106
# ['months_since_last_claim', 'number_of_open_complaints', 'number_of_policies', 'effective_to_date']
# ['customer_lifetime_value', 'income', 'monthly_premium_auto', 'months_since_policy_inception', 'total_claim_amount']

# %% [markdown]
# # Q8 & Q9

# %% [markdown]
# Q8 - For the categorical data, check if there is some kind of text in a variable so we would need to clean it. Hint: Use the same method you used in step 7. Depending on the implementation, decide what to do with the variables you get.
#
# Q9 - Get categorical features.

# %% [markdown]
# Q8 Explanation: Below function will show the outputs of the categorical functions. I could only find one column that could be cleaned (Policy) frmo 9 options into 3 options, but I will not clean it now as I do not understand the scope of th analysis yet. It doesn't make sense to reduce the data until I know what problem I a looking to solve.

# %%
catcols_list = list(categorical.columns)
for col in catcols_list:
    item_counts = categorical[col].value_counts()
    print(col, ': ', len(item_counts))
    if col != 'customer':
        print(item_counts)
        print()
# Out:
# customer :  9134
# state :  5
# California    3150
# Oregon        2601
# Arizona       1703
# Nevada         882
# Washington     798
# Name: state, dtype: int64
#
# response :  2
# No     7826
# Yes    1308
# Name: response, dtype: int64
#
# coverage :  3
# Basic       5568
# Extended    2742
# Premium      824
# Name: coverage, dtype: int64
#
# education :  5
# Bachelor                2748
# College                 2681
# High School or Below    2622
# Master                   741
# Doctor                   342
# Name: education, dtype: int64
#
# employment_status :  5
# Employed         5698
# Unemployed       2317
# Medical Leave     432
# Disabled          405
# Retired           282
# Name: employment_status, dtype: int64
#
# gender :  2
# F    4658
# M    4476
# Name: gender, dtype: int64
#
# location_code :  3
# Suburban    5779
# Rural       1773
# Urban       1582
# Name: location_code, dtype: int64
#
# marital_status :  3
# Married     5298
# Single      2467
# ...

# %% [markdown]
# # Q9

# %% [markdown]
# What should we do with the customer_id column?

# %% [markdown]
# Client_ID is not required for our analysis, and may cause issues using this column.
#
# However, we will want to convert it as the index to the cetogorical dataset to keep the relation of the rows to the right customer and then drop the column.

# %%
categorical = categorical.set_index(categorical['customer'])
categorical.head()
# Out:
#          customer       state response  coverage education employment_status  \
# customer
# BU79786   BU79786  Washington       No     Basic  Bachelor          Employed
# QZ44356   QZ44356     Arizona       No  Extended  Bachelor        Unemployed
# AI49188   AI49188      Nevada       No   Premium  Bachelor          Employed
# WW63253   WW63253  California       No     Basic  Bachelor        Unemployed
# HB64268   HB64268  Washington       No     Basic  Bachelor          Employed
#
#          gender location_code marital_status     policy_type        policy  \
# customer
# BU79786       F      Suburban        Married  Corporate Auto  Corporate L3
# QZ44356       F      Suburban         Single   Personal Auto   Personal L3
# AI49188       F      Suburban        Married   Personal Auto   Personal L3
# WW63253       M      Suburban        Married  Corporate Auto  Corporate L2
# HB64268       M         Rural         Single   Personal Auto   Personal L1
#
# ...

# %%
categorical.drop(['customer'], axis=1)
# Out:
#                state response  coverage education employment_status gender  \
# customer
# BU79786   Washington       No     Basic  Bachelor          Employed      F
# QZ44356      Arizona       No  Extended  Bachelor        Unemployed      F
# AI49188       Nevada       No   Premium  Bachelor          Employed      F
# WW63253   California       No     Basic  Bachelor        Unemployed      M
# HB64268   Washington       No     Basic  Bachelor          Employed      M
# ...              ...      ...       ...       ...               ...    ...
# LA72316   California       No     Basic  Bachelor          Employed      M
# PK87824   California      Yes  Extended   College          Employed      F
# TD14365   California       No  Extended  Bachelor        Unemployed      M
# UP19263   California       No  Extended   College          Employed      M
# Y167826   California       No  Extended   College        Unemployed      M
#
# ...
